# %%
from bs4 import BeautifulSoup
import urllib
import sys  
import os
from PyQt4.QtGui import *  
from PyQt4.QtCore import *  
from PyQt4.QtWebKit import *  
from lxml import html 
import dryscrape
import pickle
import json
from unidecode import unidecode

# %%
class SeasonData(object):
    
    def __init__(self, year):
        self.year = year
        print self.year
        self.season = self.season_links(self.year)
        
        for gameName,game in self.season.iteritems():
            
            if not os.path.exists(path + year + "/" + game['homeTeam'] + '_' + game['awayTeam'] + ".pkl"):
                
                print gameName
                game['match_stats'] = self.match_stats(game['link'])
                game['home_players'], game['away_players'] = self.player_links(game['link'])
                
                for playerName, player in game['home_players'].iteritems():
                    print playerName
                    player['player_stats'] = self.player_stats(player['link'])
                for playerName, player in game['away_players'].iteritems():
                    print playerName
                    player['player_stats'] = self.player_stats(player['link'])
                
                output = open(year + "/" + game['homeTeam'] + '_' + game['awayTeam'] + ".pkl", 'wb')
                pickle.dump(game, output, protocol=2)
                output.close()
                
                
        
        
    #list of all mathces in list links
    def season_links(self, year):
        resultsPage = urllib.urlopen("http://www.fourfourtwo.com/statszone/results/8-" + year)
        resultsPageSoup = BeautifulSoup(resultsPage, 'html5lib')
        scores = resultsPageSoup.findAll('td', {'class': 'score'})
        homeTeams = resultsPageSoup.findAll('td', {'class': 'home-team'})
        awayTeams = resultsPageSoup.findAll('td', {'class': 'away-team'})
        #matches = [homeTeams[i].contents[0].strip()+"_"+awayTeams[i].contents[0].strip() for i in range(0,len(homeTeams))]
        gamesStatsLinks = ['http://www.fourfourtwo.com' + 
                           l.a['href'] for l in resultsPageSoup.findAll('td', {'class': 'link-to-match'})]

        season = {}

        for i in range(0,len(homeTeams)):
            season[homeTeams[i].contents[0].replace(" ", "") + "_" + awayTeams[i].contents[0].replace(" ", "")] = {
                "homeTeam":str(homeTeams[i].contents[0]),
                "awayTeam":str(awayTeams[i].contents[0]),
                "homeGoals":int(scores[i].contents[0].split("-")[0]),
                "awayGoals":int(scores[i].contents[0].split("-")[1]),
                "link":str(gamesStatsLinks[i])
            }

        return(season)
    
    
    
    def match_stats(self, link):
        resultsPage = urllib.urlopen(link)
        resultsPageSoup = BeautifulSoup(resultsPage)

        #overall statistics
        match_stats = {}
        possession = resultsPageSoup.findAll('div', {'id':'summary_possessions'})[0].findAll('svg', {'class': 'doughnut_chart'})[0].text
        match_stats['home_possession'] = float(possession.split('%')[0])
        match_stats['away_possession'] = float(possession.split('%')[1])


        match_stats['home_pass_cmplt'] = int(resultsPageSoup.findAll('div', {'id':'summary_passes'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
        match_stats['away_pass_cmplt'] = int(resultsPageSoup.findAll('div', {'id':'summary_passes'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

        match_stats['home_crnr'] = int(resultsPageSoup.findAll('div', {'id':'summary_corners'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
        match_stats['away_crnr'] = int(resultsPageSoup.findAll('div', {'id':'summary_corners'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

        match_stats['home_attck_pass'] = int(resultsPageSoup.findAll('div', {'id':'summary_attacking'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
        match_stats['away_attck_pass']= int(resultsPageSoup.findAll('div', {'id':'summary_attacking'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

        match_stats['home_shots'] = int(resultsPageSoup.findAll('div', {'id':'summary_shots'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
        match_stats['away_shots'] = int(resultsPageSoup.findAll('div', {'id':'summary_shots'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

        match_stats['home_fouls'] = int(resultsPageSoup.findAll('div', {'id':'summary_fouls'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
        match_stats['away_fouls'] = int(resultsPageSoup.findAll('div', {'id':'summary_fouls'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

        match_stats['date_location'] = resultsPageSoup.findAll('div', {'class': 'teams'})[0].next.strip()

        match_stats['date'] = str(match_stats['date_location'].split(',')[-2])
        match_stats['time'] = str(match_stats['date_location'].split('-')[-1])
        return(match_stats)


    def player_links(self, game_link):
        url = game_link + '/player-stats#tabs-wrapper-anchor'
        session = dryscrape.Session()
        session.visit(url)
        formatted_result = session.body()

        soup = BeautifulSoup(formatted_result, 'html5lib')
        home_players = soup.findAll('div', {'class': 'lineup home'})
        away_players = soup.findAll('div', {'class': 'lineup away'})


        home_player_urls = ['http://www.fourfourtwo.com' + player.findAll('a')[0]['href'] 
           for player in home_players]
        home_player_names = [player.findAll('a')[0].contents
           for player in home_players]

        away_player_urls = ['http://www.fourfourtwo.com' + player.findAll('a')[0]['href'] 
           for player in away_players]
        away_player_names = [player.findAll('a')[0].contents
           for player in away_players]

        home_players = {}
        for i in range(len(home_player_names)):
            home_players[str(unidecode(home_player_names[i][0]))] = {"link":str(home_player_urls[i]) }

        away_players = {}
        for i in range(len(away_player_names)):
            away_players[str(unidecode(away_player_names[i][0]))] = {"link":str(away_player_urls[i]) }

        return(home_players, away_players)


    
    def player_stats(self, url):
        #
        
        session = dryscrape.Session()
        session.visit(url)
        playerPageFormatted = session.body()
        playerSoup = BeautifulSoup(playerPageFormatted, 'html5lib')

        match_stats = {}
        #passes
        match_stats['pass_success'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallblue)'}))
        match_stats['pass_fail'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallred)'}))
        match_stats['chances'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smalldeepskyblue)'}))
        match_stats['assists'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallyellow)'}))

        #shots
        match_stats['on_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'}))
        match_stats['off_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigredend)'}))
        match_stats['on_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'}))
        match_stats['goals'] = len(playerSoup.findAll('line', {'marker-start': 'url(#bigyellowend)'}))

        #takeons
        match_stats['takeon_success'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/success.png'}))
        match_stats['takeon_fail'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/fail.png'}))

        #defensive
        match_stats['fail_tkl'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png'}))
        match_stats['success_tkl'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png'}))
        match_stats['success_clearence'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearence.png'}))
        match_stats['failed_clearence'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearence.png'}))
        match_stats['interception'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png'}))
        match_stats['ball_recovery'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/defensive-ball-clearence.png'}))
        match_stats['blocks'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png'}))
        match_stats['blocks_cross'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks-cross.png'}))

        #aerial
        match_stats['aerial_won'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/won.png'}))
        match_stats['aerial_lost'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/lost.png'}))

        #fouls
        match_stats['foul_cmt'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png'}))
        match_stats['foul_sfr'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/suffered.png'}))

        #errors
        match_stats['error_goal'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-goal.png'}))
        match_stats['error_shot'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-shot.png'}))

        return(match_stats)

# %%
game = {'a':1, 'b':2, 'c':3}

output = open("test"+ ".pkl", 'wb')
pickle.dump(game, output)

# %%
#list of all mathces in list links
def season_links(year):
    resultsPage = urllib.urlopen("http://www.fourfourtwo.com/statszone/results/8-" + year)
    resultsPageSoup = BeautifulSoup(resultsPage, 'html5lib')
    scores = resultsPageSoup.findAll('td', {'class': 'score'})
    homeTeams = resultsPageSoup.findAll('td', {'class': 'home-team'})
    awayTeams = resultsPageSoup.findAll('td', {'class': 'away-team'})
    #matches = [homeTeams[i].contents[0].strip()+"_"+awayTeams[i].contents[0].strip() for i in range(0,len(homeTeams))]
    gamesStatsLinks = ['http://www.fourfourtwo.com' + 
                       l.a['href'] for l in resultsPageSoup.findAll('td', {'class': 'link-to-match'})]

    season = {}

    for i in range(0,len(homeTeams)):
        season[homeTeams[i].contents[0].replace(" ", "") + "_" + awayTeams[i].contents[0].replace(" ", "")] = {
            "homeTeam":str(homeTeams[i].contents[0]),
            "awayTeam":str(awayTeams[i].contents[0]),
            "homeGoals":int(scores[i].contents[0].split("-")[0]),
            "awayGoals":int(scores[i].contents[0].split("-")[1]),
            "link":str(gamesStatsLinks[i])
        }

    return(season)



def match_stats(link):
    resultsPage = urllib.urlopen(link)
    resultsPageSoup = BeautifulSoup(resultsPage)

    #overall statistics
    match_stats = {}
    possession = resultsPageSoup.findAll('div', {'id':'summary_possessions'})[0].findAll('svg', {'class': 'doughnut_chart'})[0].text
    match_stats['home_possession'] = float(possession.split('%')[0])
    match_stats['away_possession'] = float(possession.split('%')[1])


    match_stats['home_pass_cmplt'] = int(resultsPageSoup.findAll('div', {'id':'summary_passes'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_pass_cmplt'] = int(resultsPageSoup.findAll('div', {'id':'summary_passes'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['home_crnr'] = int(resultsPageSoup.findAll('div', {'id':'summary_corners'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_crnr'] = int(resultsPageSoup.findAll('div', {'id':'summary_corners'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['home_attck_pass'] = int(resultsPageSoup.findAll('div', {'id':'summary_attacking'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_attck_pass']= int(resultsPageSoup.findAll('div', {'id':'summary_attacking'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['home_shots'] = int(resultsPageSoup.findAll('div', {'id':'summary_shots'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_shots'] = int(resultsPageSoup.findAll('div', {'id':'summary_shots'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['home_fouls'] = int(resultsPageSoup.findAll('div', {'id':'summary_fouls'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_fouls'] = int(resultsPageSoup.findAll('div', {'id':'summary_fouls'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['date_location'] = resultsPageSoup.findAll('div', {'class': 'teams'})[0].next.strip()

    match_stats['date'] = str(match_stats['date_location'].split(',')[-2])
    match_stats['time'] = str(match_stats['date_location'].split('-')[-1])
    return(match_stats)


def player_links(game_link):
    url = game_link + '/player-stats#tabs-wrapper-anchor'
    session = dryscrape.Session()
    session.visit(url)
    formatted_result = session.body()

    soup = BeautifulSoup(formatted_result, 'html5lib')
    home_players = soup.findAll('div', {'class': 'lineup home'})
    away_players = soup.findAll('div', {'class': 'lineup away'})


    home_player_urls = ['http://www.fourfourtwo.com' + player.findAll('a')[0]['href'] 
       for player in home_players]
    home_player_names = [player.findAll('a')[0].contents
       for player in home_players]

    away_player_urls = ['http://www.fourfourtwo.com' + player.findAll('a')[0]['href'] 
       for player in away_players]
    away_player_names = [player.findAll('a')[0].contents
       for player in away_players]

    home_players = {}
    for i in range(len(home_player_names)):
        home_players[str(unidecode(home_player_names[i][0]))] = {"link":str(home_player_urls[i]) }

    away_players = {}
    for i in range(len(away_player_names)):
        away_players[str(unidecode(away_player_names[i][0]))] = {"link":str(away_player_urls[i]) }

    return(home_players, away_players)



def player_stats(url):
    #

    session = dryscrape.Session()
    session.visit(url)
    playerPageFormatted = session.body()
    playerSoup = BeautifulSoup(playerPageFormatted, 'html5lib')

    match_stats = {}
    #passes
    match_stats['pass_success'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallblue)'}))
    match_stats['pass_fail'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallred)'}))
    match_stats['chances'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smalldeepskyblue)'}))
    match_stats['assists'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallyellow)'}))

    #shots
    match_stats['on_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'}))
    match_stats['off_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigredend)'}))
    match_stats['on_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'}))
    match_stats['goals'] = len(playerSoup.findAll('line', {'marker-start': 'url(#bigyellowend)'}))

    #takeons
    match_stats['takeon_success'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/success.png'}))
    match_stats['takeon_fail'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/fail.png'}))

    #defensive
    match_stats['fail_tkl'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png'}))
    match_stats['success_tkl'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png'}))
    match_stats['success_clearence'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearence.png'}))
    match_stats['failed_clearence'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearence.png'}))
    match_stats['interception'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png'}))
    match_stats['ball_recovery'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/defensive-ball-clearence.png'}))
    match_stats['blocks'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png'}))
    match_stats['blocks_cross'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks-cross.png'}))

    #aerial
    match_stats['aerial_won'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/won.png'}))
    match_stats['aerial_lost'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/lost.png'}))

    #fouls
    match_stats['foul_cmt'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png'}))
    match_stats['foul_sfr'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/suffered.png'}))

    #errors
    match_stats['error_goal'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-goal.png'}))
    match_stats['error_shot'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-shot.png'}))

    return(match_stats)

# %%
year = "2015"
season = season_links(year)

for gameName,game in season.iteritems():

    if not os.path.exists(year + "/" + game['homeTeam'] + '_' + game['awayTeam'] + ".pkl"):

        print gameName
        game['match_stats'] = match_stats(game['link'])
        game['home_players'], game['away_players'] = player_links(game['link'])

        for playerName, player in game['home_players'].iteritems():
            print playerName
            player['player_stats'] = player_stats(player['link'])
        for playerName, player in game['away_players'].iteritems():
            print playerName
            player['player_stats'] = player_stats(player['link'])

        output = open(year + "/" + game['homeTeam'] + '_' + game['awayTeam'] + ".pkl", 'wb')
        pickle.dump(game, output)
        output.close()
# Out:
# SwanseaCity_LeicesterCity
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/lucas/anaconda2/envs/football/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Routledge
# Taylor
# Sigurdsson
# Bartley
# Ki
# Fabianski
# Naughton
# Ayew
# Gomis
# Britton
# Williams
# Vardy
# Fuchs
# Drinkwater
# Mahrez
# Schmeichel
# Albrighton
# Ulloa
# Huth
# Morgan
# Kante
# Simpson
# Arsenal_TottenhamHotspur
# Sanchez
# Cazorla
# Giroud
# Mertesacker
# Ozil
# Monreal
# Debuchy
# Campbell
# Cech
# Coquelin
# Koscielny
# Vertonghen
# Kane
# Eriksen
# Lamela
# Rose
# Dembele
# Alli
# Lloris
# Alderweireld
# Walker
# Dier
# NewcastleUnited_WestHamUnited
# Colback
# Elliot
# Dummett
# Wijnaldum
# Perez Gutierrez
# Shelvey
# Sissoko
# Janmaat
# Mbemba
# Mitrovic
# Coloccini
# Payet
# Noble
# Kouyate
# Tomkins
# Antonio
# San Miguel del Castillo
# Valencia
# Collins
# Obiang
# Cresswell
# Ogbonna
# LeicesterCity_Arsenal
# Schlupp
# Vardy
# de Laet
# Drinkwater
# Mahrez
# Schmeichel
# Albrighton
# Huth
# Morgan
# Okazaki
# Kante
# Sanchez
# Walcott
# Cazorla
# Flamini
# Bellerin
# Mertesacker
# Ozil
# Monreal
# Ramsey
# Cech
# Koscielny
# SwanseaCity_WestBromwichAlbion
# Routledge
# Taylor
# Sigurdsson
# Ki
# Fabianski
# Rangel
# Ayew
# Fernandez
# Britton
# Montero
# Williams
# Evans
# Lambert
# Gardner
# Yacob
# Fletcher
# Brunt
# Myhill
# Dawson
# Morrison
# Olsson
# McAuley
# CrystalPalace_AstonVilla
# Sako
# Zaha
# Puncheon
# McCarthy
# McArthur
# Dann
# Murray
# Delaney
# Souare
# Ward
# Cabaye
# Sanchez
# Gueye
# Bacuna
# Clark
# Amavi
# Grealish
# Guzan
# Gestede
# Richards
# Agbonlahor
# Westwood
# SwanseaCity_Bournemouth
# Routledge
# Taylor
# Bartley
# Ki
# Fabianski
# Shelvey
# Naughton
# Ayew
# Britton
# Macedo Lopes
# Williams
# King
# Arter
# Federici
# Daniels
# Surman
# Gosling
# Distin
# Stanislas
# Cook
# Ritchie
# Francis
# Watford_TottenhamHotspur
# Ighalo
# Gomes
# Jurado Marin
# Watson
# Capoue
# Deeney
# Cathcart
# Abdi
# Anya
# Ake
# Britos
# Vertonghen
# Kane
# Dier
# Rose
# Dembele
# Carroll
# Alli
# Lamela
# Lloris
# Alderweireld
# Trippier
# Liverpool_Everton
# Mignolet
# Clyne
# Milner
# Lovren
# Sakho
# Lallana
# Barbosa de Oliveira
# Moreno
# Coutinho
# Leiva
# Origi
# Oviedo
# Stones
# Lukaku
# Barry
# Barkley
# McCarthy
# Baines
# Robles
# Lennon
# Funes Mori
# Mirallas
# TottenhamHotspur_AstonVilla
# Vertonghen
# Kane
# Eriksen
# Lamela
# Rose
# Dembele
# Alli
# Lloris
# Alderweireld
# Walker
# Dier
# Sanchez
# Bacuna
# Guzan
# Clark
# Grealish
# Hutton
# Lescott
# Agbonlahor
# Richardson
# Westwood
# Sinclair
# Southampton_Liverpool
# van Dijk
# ---------------------------------------------------------------------------
# InvalidResponseError                      Traceback (most recent call last)
# <ipython-input-4-39db1455590b> in <module>()
#      12         for playerName, player in game['home_players'].iteritems():
#      13             print playerName
# ---> 14             player['player_stats'] = player_stats(player['link'])
#      15         for playerName, player in game['away_players'].iteritems():
#      16             print playerName
#
# <ipython-input-3-a4b945e8998b> in player_stats(url)
#      97
#      98     session = dryscrape.Session()
# ---> 99     session.visit(url)
#     100     playerPageFormatted = session.body()
#     101     playerSoup = BeautifulSoup(playerPageFormatted, 'html5lib')
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/dryscrape/session.pyc in visit(self, url)
#      31     """ Passes through the URL to the driver after completing it using the
#      32     instance's URL base. """
# ---> 33     return self.driver.visit(self.complete_url(url))
#      34
#      35   def complete_url(self, url):
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/webkit_server.pyc in visit(self, url)
#     233   def visit(self, url):
#     234     """ Goes to a given URL. """
# --> 235     self.conn.issue_command("Visit", url)
#     236
#     237   def body(self):
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/webkit_server.pyc in issue_command(self, cmd, *args)
#     518       self._sock.sendall(arg.encode("utf-8"))
#     519
# --> 520     return self._read_response()
#     521
#     522   def _read_response(self):
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/webkit_server.pyc in _read_response(self)
#     528     msg = self._read_message()
#     529     if result != "ok":
# --> 530       raise InvalidResponseError(msg)
#     531
#     532     return msg
#
# InvalidResponseError: {"class":"InvalidResponseError","message":"Unable to load URL: http://www.fourfourtwo.com/statszone/8-2015/matches/803466/player-stats/97032/OVERALL_02#tabs-wrapper-anchor because of error loading http://www.fourfourtwo.com/statszone/8-2015/matches/803466/player-stats/97032/OVERALL_02#tabs-wrapper-anchor: Unknown error"}

# %%
output = open(year + "/" + game['homeTeam'] + '_' + game['awayTeam'] + ".pkl", 'wb')
pickle.dump(game, output)
output.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-7cd067721cf3> in <module>()
#       1 output = open(year + "/" + game['homeTeam'] + '_' + game['awayTeam'] + ".pkl", 'wb')
# ----> 2 pickle.dump(game, output)
#       3 output.close()
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in dump(obj, file, protocol)
#    1374
#    1375 def dump(obj, file, protocol=None):
# -> 1376     Pickler(file, protocol).dump(obj)
#    1377
#    1378 def dumps(obj, protocol=None):
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in dump(self, obj)
#     222         if self.proto >= 2:
#     223             self.write(PROTO + chr(self.proto))
# --> 224         self.save(obj)
#     225         self.write(STOP)
#     226
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     653
#     654         self.memoize(obj)
# --> 655         self._batch_setitems(obj.iteritems())
#     656
#     657     dispatch[DictionaryType] = save_dict
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     667             for k, v in items:
#     668                 save(k)
# --> 669                 save(v)
#     670                 write(SETITEM)
#     671             return
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     653
#     654         self.memoize(obj)
# --> 655         self._batch_setitems(obj.iteritems())
#     656
#     657     dispatch[DictionaryType] = save_dict
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     666         if not self.bin:
#     667             for k, v in items:
# --> 668                 save(k)
#     669                 save(v)
#     670                 write(SETITEM)
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save(self, obj)
#     329
#     330         # Save the reduce() output and finally memoize the object
# --> 331         self.save_reduce(obj=obj, *rv)
#     332
#     333     def persistent_id(self, obj):
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     423
#     424         if state is not None:
# --> 425             save(state)
#     426             write(BUILD)
#     427
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     653
#     654         self.memoize(obj)
# --> 655         self._batch_setitems(obj.iteritems())
#     656
#     657     dispatch[DictionaryType] = save_dict
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     667             for k, v in items:
#     668                 save(k)
# --> 669                 save(v)
#     670                 write(SETITEM)
#     671             return
#
# ... last 5 frames repeated, from the frame below ...
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/pickle.pyc in save(self, obj)
#     329
#     330         # Save the reduce() output and finally memoize the object
# --> 331         self.save_reduce(obj=obj, *rv)
#     332
#     333     def persistent_id(self, obj):
#
# RuntimeError: maximum recursion depth exceeded while getting the str of an object

# %%
game
# Out:
# {'awayGoals': 1,
#  'awayTeam': u'West Bromwich Albion',
#  'away_players': {u'Berahino': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/91972/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 0,
#     'aerial_won': 0,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 2,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 2,
#     'pass_success': 18,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Brunt': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/19151/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 2,
#     'aerial_won': 4,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 1,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 3,
#     'failed_clearence': 0,
#     'foul_cmt': 2,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 4,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 23,
#     'pass_success': 22,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Dawson': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/60232/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 3,
#     'aerial_won': 4,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 1,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 1,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 16,
#     'pass_success': 16,
#     'success_clearence': 0,
#     'success_tkl': 2,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Evans': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/37642/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 3,
#     'aerial_won': 2,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 3,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 2,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 9,
#     'pass_success': 20,
#     'success_clearence': 0,
#     'success_tkl': 1,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Fletcher': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/14295/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 0,
#     'aerial_won': 2,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 1,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 2,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 1,
#     'goals': 0,
#     'interception': 3,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 5,
#     'pass_success': 26,
#     'success_clearence': 0,
#     'success_tkl': 2,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'McAuley': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/19272/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 4,
#     'aerial_won': 3,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 1,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 2,
#     'goals': 0,
#     'interception': 4,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 12,
#     'pass_success': 9,
#     'success_clearence': 0,
#     'success_tkl': 2,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'McClean': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/63370/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 2,
#     'aerial_won': 2,
#     'assists': 1,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 1,
#     'failed_clearence': 0,
#     'foul_cmt': 2,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 14,
#     'pass_success': 22,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 1,
#     'takeon_success': 3}},
#   u'Myhill': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/12086/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 0,
#     'aerial_won': 0,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 1,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 30,
#     'pass_success': 6,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Rond\xf3n': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/57134/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 5,
#     'aerial_won': 1,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 1,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 1,
#     'goals': 1,
#     'interception': 1,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 6,
#     'pass_success': 8,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Sessegnon': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/34392/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 2,
#     'aerial_won': 1,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 1,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 1,
#     'foul_sfr': 2,
#     'goals': 0,
#     'interception': 1,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 12,
#     'pass_success': 27,
#     'success_clearence': 0,
#     'success_tkl': 2,
#     'takeon_fail': 1,
#     'takeon_success': 1}},
#   u'Yacob': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/55829/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 1,
#     'aerial_won': 5,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 1,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 2,
#     'failed_clearence': 0,
#     'foul_cmt': 1,
#     'foul_sfr': 1,
#     'goals': 0,
#     'interception': 7,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 9,
#     'pass_success': 26,
#     'success_clearence': 0,
#     'success_tkl': 1,
#     'takeon_fail': 0,
#     'takeon_success': 1}}},
#  'homeGoals': 0,
#  'homeTeam': u'Norwich City',
#  'home_players': {u'Bassong': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/42744/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 1,
#     'aerial_won': 5,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 1,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 2,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 9,
#     'pass_success': 29,
#     'success_clearence': 0,
#     'success_tkl': 1,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Bennett': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/41727/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 0,
#     'aerial_won': 4,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 2,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 5,
#     'pass_success': 42,
#     'success_clearence': 0,
#     'success_tkl': 1,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Brady': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/90517/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 1,
#     'aerial_won': 5,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 1,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 1,
#     'failed_clearence': 0,
#     'foul_cmt': 1,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 2,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 22,
#     'pass_success': 51,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 1,
#     'takeon_success': 2}},
#   u'Hoolahan': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/28499/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 1,
#     'aerial_won': 0,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 2,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 1,
#     'failed_clearence': 0,
#     'foul_cmt': 1,
#     'foul_sfr': 1,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 10,
#     'pass_success': 35,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Howson': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/38297/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 2,
#     'aerial_won': 0,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 3,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 1,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 12,
#     'pass_success': 36,
#     'success_clearence': 0,
#     'success_tkl': 2,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Jarvis': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/18818/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 3,
#     'aerial_won': 0,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 2,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 16,
#     'pass_success': 25,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 1,
#     'takeon_success': 2}},
#   u'Martin': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/19341/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 1,
#     'aerial_won': 2,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 1,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 1,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 19,
#     'pass_success': 56,
#     'success_clearence': 0,
#     'success_tkl': 3,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Mbokani Bezua': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/39472/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 9,
#     'aerial_won': 5,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 1,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 2,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 3,
#     'pass_success': 13,
#     'success_clearence': 0,
#     'success_tkl': 1,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Redmond': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/83283/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 5,
#     'aerial_won': 0,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 3,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 2,
#     'failed_clearence': 0,
#     'foul_cmt': 2,
#     'foul_sfr': 1,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 19,
#     'pass_success': 30,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 2,
#     'takeon_success': 3}},
#   u'Ruddy': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/19236/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 0,
#     'aerial_won': 0,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 0,
#     'failed_clearence': 0,
#     'foul_cmt': 0,
#     'foul_sfr': 0,
#     'goals': 0,
#     'interception': 0,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 14,
#     'pass_success': 19,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 0,
#     'takeon_success': 0}},
#   u'Tettey': {'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261/player-stats/18665/OVERALL_02#tabs-wrapper-anchor',
#    'player_stats': {'aerial_lost': 1,
#     'aerial_won': 1,
#     'assists': 0,
#     'ball_recovery': 0,
#     'blocks': 0,
#     'blocks_cross': 0,
#     'chances': 0,
#     'error_goal': 0,
#     'error_shot': 0,
#     'fail_tkl': 1,
#     'failed_clearence': 0,
#     'foul_cmt': 1,
#     'foul_sfr': 2,
#     'goals': 0,
#     'interception': 2,
#     'off_target': 0,
#     'on_target': 0,
#     'pass_fail': 4,
#     'pass_success': 57,
#     'success_clearence': 0,
#     'success_tkl': 0,
#     'takeon_fail': 0,
#     'takeon_success': 3}}},
#  'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261',
#  'match_stats': {'away_attck_pass': 100,
#   'away_crnr': 3,
#   'away_fouls': 6,
#   'away_pass_cmplt': 195,
#   'away_possession': 39.0,
#   'away_shots': 7,
#   'date': ' October 24',
#   'date_location': u'Carrow Road Norwich, Saturday, October 24, 2015 - 15:00',
#   'home_attck_pass': 185,
#   'home_crnr': 13,
#   'home_fouls': 11,
#   'home_pass_cmplt': 375,
#   'home_possession': 61.0,
#   'home_shots': 16,
#   'time': ' 15:00'}}
