# %%
from bs4 import BeautifulSoup
import urllib
import sys  
from PyQt4.QtGui import *  
from PyQt4.QtCore import *  
from PyQt4.QtWebKit import *  
from lxml import html 
import dryscrape

# %%
session = dryscrape.Session()
session.visit(my_url)
response = session.body()
soup = BeautifulSoup(response)

# %%
#class for rendering js pages for use with BS
class Render(QWebPage):  
    def __init__(self, url):  
        self.app = QApplication(sys.argv)  
        QWebPage.__init__(self)  
        self.loadFinished.connect(self._loadFinished)  
        self.mainFrame().load(QUrl(url))  
        self.app.exec_()  
  
    def _loadFinished(self, result):  
        self.frame = self.mainFrame()  
        self.app.quit()

# %%
#list of all mathces in list links
def season_links(year):
    resultsPage = urllib.urlopen("http://www.fourfourtwo.com/statszone/results/8-" + year)
    resultsPageSoup = BeautifulSoup(resultsPage)
    scores = resultsPageSoup.findAll('td', {'class': 'score'})
    homeTeams = resultsPageSoup.findAll('td', {'class': 'home-team'})
    awayTeams = resultsPageSoup.findAll('td', {'class': 'away-team'})
    #matches = [homeTeams[i].contents[0].strip()+"_"+awayTeams[i].contents[0].strip() for i in range(0,len(homeTeams))]
    gamesStatsLinks = ['http://www.fourfourtwo.com' + 
                       l.a['href'] for l in resultsPageSoup.findAll('td', {'class': 'link-to-match'})]

    season = {}
    
    for i in range(0,len(homeTeams)):
        season[homeTeams[i].contents[0].strip() + "_" + awayTeams[i].contents[0].strip()] = {
            "homeTeam":homeTeams[i].contents[0],
            "awayTeam":awayTeams[i].contents[0],
            "homeGoals":int(scores[i].contents[0].split("-")[0]),
            "awayGoals":int(scores[i].contents[0].split("-")[1]),
            "link":gamesStatsLinks[i]
        }
    
    return(season)

# %%
test = season_links("2015")
test
# Out:
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/lucas/anaconda2/envs/football/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# {u'Arsenal_Aston Villa': {'awayGoals': 0,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 4,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803532'},
#  u'Arsenal_Bournemouth': {'awayGoals': 0,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 2,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803343'},
#  u'Arsenal_Chelsea': {'awayGoals': 1,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 0,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803384'},
#  u'Arsenal_Crystal Palace': {'awayGoals': 1,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803493'},
#  u'Arsenal_Everton': {'awayGoals': 1,
#   'awayTeam': u'Everton',
#   'homeGoals': 2,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803254'},
#  u'Arsenal_Leicester City': {'awayGoals': 1,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 2,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803412'},
#  u'Arsenal_Liverpool': {'awayGoals': 0,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 0,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803185'},
#  u'Arsenal_Manchester City': {'awayGoals': 1,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 2,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803327'},
#  u'Arsenal_Manchester United': {'awayGoals': 0,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 3,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803234'},
#  u'Arsenal_Newcastle United': {'awayGoals': 0,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 1,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803357'},
#  u'Arsenal_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 1,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803518'},
#  u'Arsenal_Southampton': {'awayGoals': 0,
#   'awayTeam': u'Southampton',
#   'homeGoals': 0,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803397'},
#  u'Arsenal_Stoke City': {'awayGoals': 0,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 2,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803209'},
#  u'Arsenal_Sunderland': {'awayGoals': 1,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 3,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803309'},
#  u'Arsenal_Swansea City': {'awayGoals': 2,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 1,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803437'},
#  u'Arsenal_Tottenham Hotspur': {'awayGoals': 1,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803279'},
#  u'Arsenal_Watford': {'awayGoals': 0,
#   'awayTeam': u'Watford',
#   'homeGoals': 4,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803480'},
#  u'Arsenal_West Bromwich Albion': {'awayGoals': 0,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 2,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803461'},
#  u'Arsenal_West Ham United': {'awayGoals': 2,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 0,
#   'homeTeam': u'Arsenal',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803171'},
#  u'Aston Villa_Arsenal': {'awayGoals': 2,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803312'},
#  u'Aston Villa_Bournemouth': {'awayGoals': 2,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 1,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803483'},
#  u'Aston Villa_Chelsea': {'awayGoals': 4,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803472'},
#  u'Aston Villa_Crystal Palace': {'awayGoals': 0,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803363'},
#  u'Aston Villa_Everton': {'awayGoals': 3,
#   'awayTeam': u'Everton',
#   'homeGoals': 1,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803434'},
#  u'Aston Villa_Leicester City': {'awayGoals': 1,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 1,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803375'},
#  u'Aston Villa_Liverpool': {'awayGoals': 6,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803413'},
#  u'Aston Villa_Manchester City': {'awayGoals': 0,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803275'},
#  u'Aston Villa_Manchester United': {'awayGoals': 1,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803177'},
#  u'Aston Villa_Newcastle United': {'awayGoals': 0,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803526'},
#  u'Aston Villa_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 2,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803407'},
#  u'Aston Villa_Southampton': {'awayGoals': 4,
#   'awayTeam': u'Southampton',
#   'homeGoals': 2,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803507'},
#  u'Aston Villa_Stoke City': {'awayGoals': 1,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803237'},
#  u'Aston Villa_Sunderland': {'awayGoals': 2,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 2,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803198'},
#  u'Aston Villa_Swansea City': {'awayGoals': 2,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 1,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803258'},
#  u'Aston Villa_Tottenham Hotspur': {'awayGoals': 2,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803459'},
#  u'Aston Villa_Watford': {'awayGoals': 3,
#   'awayTeam': u'Watford',
#   'homeGoals': 2,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803300'},
#  u'Aston Villa_West Bromwich Albion': {'awayGoals': 1,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 0,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803220'},
#  u'Aston Villa_West Ham United': {'awayGoals': 1,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 1,
#   'homeTeam': u'Aston Villa',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803341'},
#  u'Bournemouth_Arsenal': {'awayGoals': 2,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 0,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803402'},
#  u'Bournemouth_Aston Villa': {'awayGoals': 1,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 0,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803162'},
#  u'Bournemouth_Chelsea': {'awayGoals': 4,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 1,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803503'},
#  u'Bournemouth_Crystal Palace': {'awayGoals': 0,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 0,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803333'},
#  u'Bournemouth_Everton': {'awayGoals': 3,
#   'awayTeam': u'Everton',
#   'homeGoals': 3,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803294'},
#  u'Bournemouth_Leicester City': {'awayGoals': 1,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 1,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803195'},
#  u'Bournemouth_Liverpool': {'awayGoals': 2,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 1,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803494'},
#  u'Bournemouth_Manchester City': {'awayGoals': 4,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803475'},
#  u'Bournemouth_Manchester United': {'awayGoals': 1,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 2,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803315'},
#  u'Bournemouth_Newcastle United': {'awayGoals': 1,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 0,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803276'},
#  u'Bournemouth_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 3,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803377'},
#  u'Bournemouth_Southampton': {'awayGoals': 0,
#   'awayTeam': u'Southampton',
#   'homeGoals': 2,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803436'},
#  u'Bournemouth_Stoke City': {'awayGoals': 3,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 1,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803417'},
#  u'Bournemouth_Sunderland': {'awayGoals': 0,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 2,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803218'},
#  u'Bournemouth_Swansea City': {'awayGoals': 2,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 3,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803458'},
#  u'Bournemouth_Tottenham Hotspur': {'awayGoals': 5,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803259'},
#  u'Bournemouth_Watford': {'awayGoals': 1,
#   'awayTeam': u'Watford',
#   'homeGoals': 1,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803239'},
#  u'Bournemouth_West Bromwich Albion': {'awayGoals': 1,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 1,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803531'},
#  u'Bournemouth_West Ham United': {'awayGoals': 3,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 1,
#   'homeTeam': u'Bournemouth',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803365'},
#  u'Chelsea_Arsenal': {'awayGoals': 0,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 2,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803212'},
#  u'Chelsea_Aston Villa': {'awayGoals': 0,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 2,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803243'},
#  u'Chelsea_Bournemouth': {'awayGoals': 1,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 0,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803303'},
#  u'Chelsea_Crystal Palace': {'awayGoals': 2,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803193'},
#  u'Chelsea_Everton': {'awayGoals': 3,
#   'awayTeam': u'Everton',
#   'homeGoals': 3,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803374'},
#  u'Chelsea_Leicester City': {'awayGoals': 1,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 1,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803535'},
#  u'Chelsea_Liverpool': {'awayGoals': 3,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 1,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803266'},
#  u'Chelsea_Manchester City': {'awayGoals': 3,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803495'},
#  u'Chelsea_Manchester United': {'awayGoals': 1,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 1,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803406'},
#  u'Chelsea_Newcastle United': {'awayGoals': 1,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 5,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803415'},
#  u'Chelsea_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 1,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803288'},
#  u'Chelsea_Southampton': {'awayGoals': 3,
#   'awayTeam': u'Southampton',
#   'homeGoals': 1,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803236'},
#  u'Chelsea_Stoke City': {'awayGoals': 1,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 1,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803449'},
#  u'Chelsea_Sunderland': {'awayGoals': 1,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 3,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803329'},
#  u'Chelsea_Swansea City': {'awayGoals': 2,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 2,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803168'},
#  u'Chelsea_Tottenham Hotspur': {'awayGoals': 2,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 2,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803520'},
#  u'Chelsea_Watford': {'awayGoals': 2,
#   'awayTeam': u'Watford',
#   'homeGoals': 2,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803339'},
#  u'Chelsea_West Bromwich Albion': {'awayGoals': 2,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 2,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803371'},
#  u'Chelsea_West Ham United': {'awayGoals': 2,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 2,
#   'homeTeam': u'Chelsea',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803471'},
#  u'Crystal Palace_Arsenal': {'awayGoals': 2,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 1,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803172'},
#  u'Crystal Palace_Aston Villa': {'awayGoals': 1,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 2,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803182'},
#  u'Crystal Palace_Bournemouth': {'awayGoals': 2,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 1,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803393'},
#  u'Crystal Palace_Chelsea': {'awayGoals': 3,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 0,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803354'},
#  u'Crystal Palace_Everton': {'awayGoals': 0,
#   'awayTeam': u'Everton',
#   'homeGoals': 0,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803504'},
#  u'Crystal Palace_Leicester City': {'awayGoals': 1,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 0,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803465'},
#  u'Crystal Palace_Liverpool': {'awayGoals': 2,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 1,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803446'},
#  u'Crystal Palace_Manchester City': {'awayGoals': 1,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803206'},
#  u'Crystal Palace_Manchester United': {'awayGoals': 0,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 0,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803267'},
#  u'Crystal Palace_Newcastle United': {'awayGoals': 1,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 5,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803296'},
#  u'Crystal Palace_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 1,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803489'},
#  u'Crystal Palace_Southampton': {'awayGoals': 0,
#   'awayTeam': u'Southampton',
#   'homeGoals': 1,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803317'},
#  u'Crystal Palace_Stoke City': {'awayGoals': 1,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 2,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803528'},
#  u'Crystal Palace_Sunderland': {'awayGoals': 1,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 0,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803290'},
#  u'Crystal Palace_Swansea City': {'awayGoals': 0,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 0,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803350'},
#  u'Crystal Palace_Tottenham Hotspur': {'awayGoals': 3,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803391'},
#  u'Crystal Palace_Watford': {'awayGoals': 2,
#   'awayTeam': u'Watford',
#   'homeGoals': 1,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803419'},
#  u'Crystal Palace_West Bromwich Albion': {'awayGoals': 0,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 2,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803240'},
#  u'Crystal Palace_West Ham United': {'awayGoals': 3,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 1,
#   'homeTeam': u'Crystal Palace',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803251'},
#  u'Everton_Arsenal': {'awayGoals': 2,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 0,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803462'},
#  u'Everton_Aston Villa': {'awayGoals': 0,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 4,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803283'},
#  u'Everton_Bournemouth': {'awayGoals': 1,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 2,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803513'},
#  u'Everton_Chelsea': {'awayGoals': 1,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 3,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803204'},
#  u'Everton_Crystal Palace': {'awayGoals': 1,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803304'},
#  u'Everton_Leicester City': {'awayGoals': 3,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 2,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803325'},
#  u'Everton_Liverpool': {'awayGoals': 1,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 1,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803233'},
#  u'Everton_Manchester City': {'awayGoals': 2,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803186'},
#  u'Everton_Manchester United': {'awayGoals': 3,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 0,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803247'},
#  u'Everton_Newcastle United': {'awayGoals': 0,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 3,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803401'},
#  u'Everton_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 3,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803538'},
#  u'Everton_Southampton': {'awayGoals': 1,
#   'awayTeam': u'Southampton',
#   'homeGoals': 1,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803496'},
#  u'Everton_Stoke City': {'awayGoals': 4,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 3,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803349'},
#  u'Everton_Sunderland': {'awayGoals': 2,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 6,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803270'},
#  u'Everton_Swansea City': {'awayGoals': 2,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 1,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803390'},
#  u'Everton_Tottenham Hotspur': {'awayGoals': 1,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803361'},
#  u'Everton_Watford': {'awayGoals': 2,
#   'awayTeam': u'Watford',
#   'homeGoals': 2,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803170'},
#  u'Everton_West Bromwich Albion': {'awayGoals': 1,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 0,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803420'},
#  u'Everton_West Ham United': {'awayGoals': 3,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 2,
#   'homeTeam': u'Everton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803451'},
#  u'Leicester City_Arsenal': {'awayGoals': 5,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 2,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803222'},
#  u'Leicester City_Aston Villa': {'awayGoals': 2,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 3,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803202'},
#  u'Leicester City_Bournemouth': {'awayGoals': 0,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 0,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803353'},
#  u'Leicester City_Chelsea': {'awayGoals': 1,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 2,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803313'},
#  u'Leicester City_Crystal Palace': {'awayGoals': 0,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803253'},
#  u'Leicester City_Everton': {'awayGoals': 1,
#   'awayTeam': u'Everton',
#   'homeGoals': 3,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803524'},
#  u'Leicester City_Liverpool': {'awayGoals': 0,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 2,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803395'},
#  u'Leicester City_Manchester City': {'awayGoals': 0,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803346'},
#  u'Leicester City_Manchester United': {'awayGoals': 1,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 1,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803295'},
#  u'Leicester City_Newcastle United': {'awayGoals': 0,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 1,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803456'},
#  u'Leicester City_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 1,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803429'},
#  u'Leicester City_Southampton': {'awayGoals': 0,
#   'awayTeam': u'Southampton',
#   'homeGoals': 1,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803477'},
#  u'Leicester City_Stoke City': {'awayGoals': 0,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 3,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803389'},
#  u'Leicester City_Sunderland': {'awayGoals': 2,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 4,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803167'},
#  u'Leicester City_Swansea City': {'awayGoals': 0,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 4,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803509'},
#  u'Leicester City_Tottenham Hotspur': {'awayGoals': 1,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803191'},
#  u'Leicester City_Watford': {'awayGoals': 1,
#   'awayTeam': u'Watford',
#   'homeGoals': 2,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803280'},
#  u'Leicester City_West Bromwich Albion': {'awayGoals': 2,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 2,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803440'},
#  u'Leicester City_West Ham United': {'awayGoals': 2,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 2,
#   'homeTeam': u'Leicester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803501'},
#  u'Liverpool_Arsenal': {'awayGoals': 3,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 3,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803362'},
#  u'Liverpool_Aston Villa': {'awayGoals': 2,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 3,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803223'},
#  u'Liverpool_Bournemouth': {'awayGoals': 0,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 1,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803173'},
#  u'Liverpool_Chelsea': {'awayGoals': 1,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 1,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803452'},
#  u'Liverpool_Crystal Palace': {'awayGoals': 2,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803273'},
#  u'Liverpool_Everton': {'awayGoals': 0,
#   'awayTeam': u'Everton',
#   'homeGoals': 4,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803427'},
#  u'Liverpool_Leicester City': {'awayGoals': 0,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 1,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803335'},
#  u'Liverpool_Manchester City': {'awayGoals': 0,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 3,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803435'},
#  u'Liverpool_Manchester United': {'awayGoals': 1,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 0,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803376'},
#  u'Liverpool_Newcastle United': {'awayGoals': 2,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 2,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803506'},
#  u'Liverpool_Norwich City': {'awayGoals': 1,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 1,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803217'},
#  u'Liverpool_Southampton': {'awayGoals': 1,
#   'awayTeam': u'Southampton',
#   'homeGoals': 1,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803257'},
#  u'Liverpool_Stoke City': {'awayGoals': 1,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 4,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803490'},
#  u'Liverpool_Sunderland': {'awayGoals': 2,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 2,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803408'},
#  u'Liverpool_Swansea City': {'awayGoals': 0,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 1,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803299'},
#  u'Liverpool_Tottenham Hotspur': {'awayGoals': 1,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803479'},
#  u'Liverpool_Watford': {'awayGoals': 0,
#   'awayTeam': u'Watford',
#   'homeGoals': 2,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803530'},
#  u'Liverpool_West Bromwich Albion': {'awayGoals': 2,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 2,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803321'},
#  u'Liverpool_West Ham United': {'awayGoals': 3,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 0,
#   'homeTeam': u'Liverpool',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803201'},
#  u'Manchester City_Arsenal': {'awayGoals': 2,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 2,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803522'},
#  u'Manchester City_Aston Villa': {'awayGoals': 0,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 4,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803443'},
#  u'Manchester City_Bournemouth': {'awayGoals': 1,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 5,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803244'},
#  u'Manchester City_Chelsea': {'awayGoals': 0,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 3,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803174'},
#  u'Manchester City_Crystal Palace': {'awayGoals': 0,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 4,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803373'},
#  u'Manchester City_Everton': {'awayGoals': 0,
#   'awayTeam': u'Everton',
#   'homeGoals': 0,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803366'},
#  u'Manchester City_Leicester City': {'awayGoals': 3,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803405'},
#  u'Manchester City_Liverpool': {'awayGoals': 4,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803286'},
#  u'Manchester City_Manchester United': {'awayGoals': 1,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 0,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803467'},
#  u'Manchester City_Newcastle United': {'awayGoals': 1,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 6,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803235'},
#  u'Manchester City_Norwich City': {'awayGoals': 1,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 2,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803268'},
#  u'Manchester City_Southampton': {'awayGoals': 1,
#   'awayTeam': u'Southampton',
#   'homeGoals': 3,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803297'},
#  u'Manchester City_Stoke City': {'awayGoals': 0,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 4,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803508'},
#  u'Manchester City_Sunderland': {'awayGoals': 1,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 4,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803338'},
#  u'Manchester City_Swansea City': {'awayGoals': 1,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 2,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803319'},
#  u'Manchester City_Tottenham Hotspur': {'awayGoals': 2,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803418'},
#  u'Manchester City_Watford': {'awayGoals': 0,
#   'awayTeam': u'Watford',
#   'homeGoals': 2,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803199'},
#  u'Manchester City_West Bromwich Albion': {'awayGoals': 1,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 2,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803491'},
#  u'Manchester City_West Ham United': {'awayGoals': 2,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803221'},
#  u'Manchester United_Arsenal': {'awayGoals': 2,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 3,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803422'},
#  u'Manchester United_Aston Villa': {'awayGoals': 0,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803492'},
#  u'Manchester United_Bournemouth': {'awayGoals': 1,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 3,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803533'},
#  u'Manchester United_Chelsea': {'awayGoals': 0,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 0,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803344'},
#  u'Manchester United_Crystal Palace': {'awayGoals': 0,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 2,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803453'},
#  u'Manchester United_Everton': {'awayGoals': 0,
#   'awayTeam': u'Everton',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803474'},
#  u'Manchester United_Leicester City': {'awayGoals': 1,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803515'},
#  u'Manchester United_Liverpool': {'awayGoals': 1,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 3,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803205'},
#  u'Manchester United_Manchester City': {'awayGoals': 0,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803255'},
#  u'Manchester United_Newcastle United': {'awayGoals': 0,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 0,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803187'},
#  u'Manchester United_Norwich City': {'awayGoals': 2,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803328'},
#  u'Manchester United_Southampton': {'awayGoals': 1,
#   'awayTeam': u'Southampton',
#   'homeGoals': 0,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803388'},
#  u'Manchester United_Stoke City': {'awayGoals': 0,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 3,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803398'},
#  u'Manchester United_Sunderland': {'awayGoals': 0,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 3,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803230'},
#  u'Manchester United_Swansea City': {'awayGoals': 1,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 2,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803360'},
#  u'Manchester United_Tottenham Hotspur': {'awayGoals': 0,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803169'},
#  u'Manchester United_Watford': {'awayGoals': 0,
#   'awayTeam': u'Watford',
#   'homeGoals': 1,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803439'},
#  u'Manchester United_West Bromwich Albion': {'awayGoals': 0,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 2,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803281'},
#  u'Manchester United_West Ham United': {'awayGoals': 0,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 0,
#   'homeTeam': u'Manchester United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803311'},
#  u'Newcastle United_Arsenal': {'awayGoals': 1,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 0,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803192'},
#  u'Newcastle United_Aston Villa': {'awayGoals': 1,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 1,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803322'},
#  u'Newcastle United_Bournemouth': {'awayGoals': 3,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 1,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803444'},
#  u'Newcastle United_Chelsea': {'awayGoals': 2,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 2,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803225'},
#  u'Newcastle United_Crystal Palace': {'awayGoals': 0,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803514'},
#  u'Newcastle United_Everton': {'awayGoals': 1,
#   'awayTeam': u'Everton',
#   'homeGoals': 0,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803334'},
#  u'Newcastle United_Leicester City': {'awayGoals': 3,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 0,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803285'},
#  u'Newcastle United_Liverpool': {'awayGoals': 0,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 2,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803306'},
#  u'Newcastle United_Manchester City': {'awayGoals': 1,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 1,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803428'},
#  u'Newcastle United_Manchester United': {'awayGoals': 3,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 3,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803368'},
#  u'Newcastle United_Norwich City': {'awayGoals': 2,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 6,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803248'},
#  u'Newcastle United_Southampton': {'awayGoals': 2,
#   'awayTeam': u'Southampton',
#   'homeGoals': 2,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803166'},
#  u'Newcastle United_Stoke City': {'awayGoals': 0,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 0,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803269'},
#  u'Newcastle United_Sunderland': {'awayGoals': 1,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 1,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803470'},
#  u'Newcastle United_Swansea City': {'awayGoals': 0,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 3,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803498'},
#  u'Newcastle United_Tottenham Hotspur': {'awayGoals': 1,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 5,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803540'},
#  u'Newcastle United_Watford': {'awayGoals': 2,
#   'awayTeam': u'Watford',
#   'homeGoals': 1,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803219'},
#  u'Newcastle United_West Bromwich Albion': {'awayGoals': 0,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 1,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803410'},
#  u'Newcastle United_West Ham United': {'awayGoals': 1,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 2,
#   'homeTeam': u'Newcastle United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803381'},
#  u'Norwich City_Arsenal': {'awayGoals': 1,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 1,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803292'},
#  u'Norwich City_Aston Villa': {'awayGoals': 0,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 2,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803342'},
#  u'Norwich City_Bournemouth': {'awayGoals': 1,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 3,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803203'},
#  u'Norwich City_Chelsea': {'awayGoals': 2,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 1,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803432'},
#  u'Norwich City_Crystal Palace': {'awayGoals': 3,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803163'},
#  u'Norwich City_Everton': {'awayGoals': 1,
#   'awayTeam': u'Everton',
#   'homeGoals': 1,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803314'},
#  u'Norwich City_Leicester City': {'awayGoals': 2,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 1,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803232'},
#  u'Norwich City_Liverpool': {'awayGoals': 5,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 4,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803385'},
#  u'Norwich City_Manchester City': {'awayGoals': 0,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803455'},
#  u'Norwich City_Manchester United': {'awayGoals': 1,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 0,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803525'},
#  u'Norwich City_Newcastle United': {'awayGoals': 2,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 3,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803476'},
#  u'Norwich City_Southampton': {'awayGoals': 0,
#   'awayTeam': u'Southampton',
#   'homeGoals': 1,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803358'},
#  u'Norwich City_Stoke City': {'awayGoals': 1,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 1,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803189'},
#  u'Norwich City_Sunderland': {'awayGoals': 3,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 0,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803497'},
#  u'Norwich City_Swansea City': {'awayGoals': 0,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 1,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803278'},
#  u'Norwich City_Tottenham Hotspur': {'awayGoals': 3,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 0,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803400'},
#  u'Norwich City_Watford': {'awayGoals': 2,
#   'awayTeam': u'Watford',
#   'homeGoals': 4,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803510'},
#  u'Norwich City_West Bromwich Albion': {'awayGoals': 1,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 0,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803261'},
#  u'Norwich City_West Ham United': {'awayGoals': 2,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 2,
#   'homeTeam': u'Norwich City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803421'},
#  u'Southampton_Arsenal': {'awayGoals': 0,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 4,
#   'homeTeam': u'Southampton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803332'},
#  u'Southampton_Aston Villa': {'awayGoals': 1,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 1,
#   'homeTeam': u'Southampton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803302'},
#  u'Southampton_Bournemouth': {'awayGoals': 0,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 2,
#   'homeTeam': u'Southampton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803264'},
#  u'Southampton_Chelsea': {'awayGoals': 2,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 1,
#   'homeTeam': u'Southampton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803425'},
#  u'Southampton_Crystal Palace': {'awayGoals': 1,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 4,
#   'homeTeam': u'Southampton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803534'},
#  u'Southampton_Everton': {'awayGoals': 3,
#   'awayTeam': u'Everton',
#   'homeGoals': 0,
#   'homeTeam': u'Southampton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803175'},
#  u'Southampton_Leicester City': {'awayGoals': 2,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 2,
#   'homeTeam': u'Southampton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803245'},
#  u'Southampton_Liverpool': {'awayGoals': 2,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 3,
#   'homeTeam': u'Southampton',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803466'},
# ...
#   'homeTeam': u'Swansea City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803340'},
#  u'Swansea City_West Ham United': {'awayGoals': 0,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 0,
#   'homeTeam': u'Swansea City',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803331'},
#  u'Tottenham Hotspur_Arsenal': {'awayGoals': 2,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 2,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803442'},
#  u'Tottenham Hotspur_Aston Villa': {'awayGoals': 1,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 3,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803263'},
#  u'Tottenham Hotspur_Bournemouth': {'awayGoals': 0,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 3,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803464'},
#  u'Tottenham Hotspur_Chelsea': {'awayGoals': 0,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 0,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803293'},
#  u'Tottenham Hotspur_Crystal Palace': {'awayGoals': 0,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 1,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803213'},
#  u'Tottenham Hotspur_Everton': {'awayGoals': 0,
#   'awayTeam': u'Everton',
#   'homeGoals': 0,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803194'},
#  u'Tottenham Hotspur_Leicester City': {'awayGoals': 1,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 0,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803367'},
#  u'Tottenham Hotspur_Liverpool': {'awayGoals': 0,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 0,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803246'},
#  u'Tottenham Hotspur_Manchester City': {'awayGoals': 1,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 4,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803228'},
#  u'Tottenham Hotspur_Manchester United': {'awayGoals': 0,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 3,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803487'},
#  u'Tottenham Hotspur_Newcastle United': {'awayGoals': 2,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 1,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803316'},
#  u'Tottenham Hotspur_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 3,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803337'},
#  u'Tottenham Hotspur_Southampton': {'awayGoals': 2,
#   'awayTeam': u'Southampton',
#   'homeGoals': 1,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803527'},
#  u'Tottenham Hotspur_Stoke City': {'awayGoals': 2,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 2,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803180'},
#  u'Tottenham Hotspur_Sunderland': {'awayGoals': 1,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 4,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803378'},
#  u'Tottenham Hotspur_Swansea City': {'awayGoals': 1,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 2,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803431'},
#  u'Tottenham Hotspur_Watford': {'awayGoals': 0,
#   'awayTeam': u'Watford',
#   'homeGoals': 1,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803409'},
#  u'Tottenham Hotspur_West Bromwich Albion': {'awayGoals': 1,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 1,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803511'},
#  u'Tottenham Hotspur_West Ham United': {'awayGoals': 1,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 4,
#   'homeTeam': u'Tottenham Hotspur',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803291'},
#  u'Watford_Arsenal': {'awayGoals': 3,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 0,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803242'},
#  u'Watford_Aston Villa': {'awayGoals': 2,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 3,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803512'},
#  u'Watford_Bournemouth': {'awayGoals': 0,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 0,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803424'},
#  u'Watford_Chelsea': {'awayGoals': 0,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 0,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803394'},
#  u'Watford_Crystal Palace': {'awayGoals': 1,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 0,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803226'},
#  u'Watford_Everton': {'awayGoals': 1,
#   'awayTeam': u'Everton',
#   'homeGoals': 1,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803485'},
#  u'Watford_Leicester City': {'awayGoals': 1,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 0,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803445'},
#  u'Watford_Liverpool': {'awayGoals': 0,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 3,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803326'},
#  u'Watford_Manchester City': {'awayGoals': 2,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 1,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803356'},
#  u'Watford_Manchester United': {'awayGoals': 2,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 1,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803287'},
#  u'Watford_Newcastle United': {'awayGoals': 1,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 2,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803387'},
#  u'Watford_Norwich City': {'awayGoals': 0,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 2,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803308'},
#  u'Watford_Southampton': {'awayGoals': 0,
#   'awayTeam': u'Southampton',
#   'homeGoals': 0,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803188'},
#  u'Watford_Stoke City': {'awayGoals': 2,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 1,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803469'},
#  u'Watford_Sunderland': {'awayGoals': 2,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 2,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803539'},
#  u'Watford_Swansea City': {'awayGoals': 0,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 1,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803210'},
#  u'Watford_Tottenham Hotspur': {'awayGoals': 2,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803351'},
#  u'Watford_West Bromwich Albion': {'awayGoals': 0,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 0,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803181'},
#  u'Watford_West Ham United': {'awayGoals': 0,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 2,
#   'homeTeam': u'Watford',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803271'},
#  u'West Bromwich Albion_Arsenal': {'awayGoals': 1,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 2,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803282'},
#  u'West Bromwich Albion_Aston Villa': {'awayGoals': 0,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 0,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803382'},
#  u'West Bromwich Albion_Bournemouth': {'awayGoals': 2,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 1,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803323'},
#  u'West Bromwich Albion_Chelsea': {'awayGoals': 3,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 2,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803184'},
#  u'West Bromwich Albion_Crystal Palace': {'awayGoals': 2,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 3,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803426'},
#  u'West Bromwich Albion_Everton': {'awayGoals': 3,
#   'awayTeam': u'Everton',
#   'homeGoals': 2,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803227'},
#  u'West Bromwich Albion_Leicester City': {'awayGoals': 3,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 2,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803265'},
#  u'West Bromwich Albion_Liverpool': {'awayGoals': 1,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 1,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803536'},
#  u'West Bromwich Albion_Manchester City': {'awayGoals': 3,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 0,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803165'},
#  u'West Bromwich Albion_Manchester United': {'awayGoals': 0,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 1,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803447'},
#  u'West Bromwich Albion_Newcastle United': {'awayGoals': 0,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 1,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803347'},
#  u'West Bromwich Albion_Norwich City': {'awayGoals': 1,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 0,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803468'},
#  u'West Bromwich Albion_Southampton': {'awayGoals': 0,
#   'awayTeam': u'Southampton',
#   'homeGoals': 0,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803208'},
#  u'West Bromwich Albion_Stoke City': {'awayGoals': 1,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 2,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803359'},
#  u'West Bromwich Albion_Sunderland': {'awayGoals': 0,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 1,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803250'},
#  u'West Bromwich Albion_Swansea City': {'awayGoals': 1,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 1,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803399'},
#  u'West Bromwich Albion_Tottenham Hotspur': {'awayGoals': 1,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803310'},
#  u'West Bromwich Albion_Watford': {'awayGoals': 1,
#   'awayTeam': u'Watford',
#   'homeGoals': 0,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803500'},
#  u'West Bromwich Albion_West Ham United': {'awayGoals': 3,
#   'awayTeam': u'West Ham United',
#   'homeGoals': 0,
#   'homeTeam': u'West Bromwich Albion',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803521'},
#  u'West Ham United_Arsenal': {'awayGoals': 3,
#   'awayTeam': u'Arsenal',
#   'homeGoals': 3,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803482'},
#  u'West Ham United_Aston Villa': {'awayGoals': 0,
#   'awayTeam': u'Aston Villa',
#   'homeGoals': 2,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803392'},
#  u'West Ham United_Bournemouth': {'awayGoals': 4,
#   'awayTeam': u'Bournemouth',
#   'homeGoals': 3,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803183'},
#  u'West Ham United_Chelsea': {'awayGoals': 1,
#   'awayTeam': u'Chelsea',
#   'homeGoals': 2,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803252'},
#  u'West Ham United_Crystal Palace': {'awayGoals': 2,
#   'awayTeam': u'Crystal Palace',
#   'homeGoals': 2,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803473'},
#  u'West Ham United_Everton': {'awayGoals': 1,
#   'awayTeam': u'Everton',
#   'homeGoals': 1,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803274'},
#  u'West Ham United_Leicester City': {'awayGoals': 2,
#   'awayTeam': u'Leicester City',
#   'homeGoals': 1,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803176'},
#  u'West Ham United_Liverpool': {'awayGoals': 0,
#   'awayTeam': u'Liverpool',
#   'homeGoals': 2,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803355'},
#  u'West Ham United_Manchester City': {'awayGoals': 2,
#   'awayTeam': u'Manchester City',
#   'homeGoals': 2,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803386'},
#  u'West Ham United_Manchester United': {'awayGoals': 2,
#   'awayTeam': u'Manchester United',
#   'homeGoals': 3,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803505'},
#  u'West Ham United_Newcastle United': {'awayGoals': 0,
#   'awayTeam': u'Newcastle United',
#   'homeGoals': 2,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803207'},
#  u'West Ham United_Norwich City': {'awayGoals': 2,
#   'awayTeam': u'Norwich City',
#   'homeGoals': 2,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803229'},
#  u'West Ham United_Southampton': {'awayGoals': 1,
#   'awayTeam': u'Southampton',
#   'homeGoals': 2,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803348'},
#  u'West Ham United_Stoke City': {'awayGoals': 0,
#   'awayTeam': u'Stoke City',
#   'homeGoals': 0,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803318'},
#  u'West Ham United_Sunderland': {'awayGoals': 0,
#   'awayTeam': u'Sunderland',
#   'homeGoals': 1,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803430'},
#  u'West Ham United_Swansea City': {'awayGoals': 4,
#   'awayTeam': u'Swansea City',
#   'homeGoals': 1,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803529'},
#  u'West Ham United_Tottenham Hotspur': {'awayGoals': 0,
#   'awayTeam': u'Tottenham Hotspur',
#   'homeGoals': 1,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803438'},
#  u'West Ham United_Watford': {'awayGoals': 1,
#   'awayTeam': u'Watford',
#   'homeGoals': 3,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803460'},
#  u'West Ham United_West Bromwich Albion': {'awayGoals': 1,
#   'awayTeam': u'West Bromwich Albion',
#   'homeGoals': 1,
#   'homeTeam': u'West Ham United',
#   'link': 'http://www.fourfourtwo.com/statszone/8-2015/matches/803301'}}

# %%
import json
test = season_links("2015")
test
with open('out.json', 'w') as fp:
    json.dump(test, fp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-7b8061dc0fb7> in <module>()
#       3 test
#       4 with open('out.json', 'w') as fp:
# ----> 5     json.dump(test, fp)
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/json/__init__.pyc in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     187     # could accelerate with writelines in some versions of Python, at
#     188     # a debuggability cost
# --> 189     for chunk in iterable:
#     190         fp.write(chunk)
#     191
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/json/encoder.pyc in _iterencode(o, _current_indent_level)
#     432                 yield chunk
#     433         elif isinstance(o, dict):
# --> 434             for chunk in _iterencode_dict(o, _current_indent_level):
#     435                 yield chunk
#     436         else:
#
# /home/lucas/anaconda2/envs/football/lib/python2.7/json/encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     380                 continue
#     381             else:
# --> 382                 raise TypeError("key " + repr(key) + " is not a string")
#     383             if first:
#     384                 first = False
#
# TypeError: key (u'West Bromwich Albion', u'Sunderland') is not a string

# %%
def match_stats(link):
    resultsPage = urllib.urlopen(link)
    resultsPageSoup = BeautifulSoup(resultsPage)

    #overall statistics
    match_stats = {}
    possession = resultsPageSoup.findAll('div', {'id':'summary_possessions'})[0].findAll('svg', {'class': 'doughnut_chart'})[0].text
    match_stats['home_possession'] = float(possession.split('%')[0])
    match_stats['away_possession'] = float(possession.split('%')[1])
    
    
    match_stats['home_pass_cmplt'] = int(resultsPageSoup.findAll('div', {'id':'summary_passes'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_pass_cmplt'] = int(resultsPageSoup.findAll('div', {'id':'summary_passes'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['home_crnr'] = int(resultsPageSoup.findAll('div', {'id':'summary_corners'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_crnr'] = int(resultsPageSoup.findAll('div', {'id':'summary_corners'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['home_attck_pass'] = int(resultsPageSoup.findAll('div', {'id':'summary_attacking'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_attck_pass']= int(resultsPageSoup.findAll('div', {'id':'summary_attacking'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['home_shots'] = int(resultsPageSoup.findAll('div', {'id':'summary_shots'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_shots'] = int(resultsPageSoup.findAll('div', {'id':'summary_shots'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['home_fouls'] = int(resultsPageSoup.findAll('div', {'id':'summary_fouls'})[0].findAll('text', {'fill': "#FCD800"})[0].next)
    match_stats['away_fouls'] = int(resultsPageSoup.findAll('div', {'id':'summary_fouls'})[0].findAll('text', {'fill': "#E6E6E6"})[0].next)

    match_stats['date_location'] = resultsPageSoup.findAll('div', {'class': 'teams'})[0].next.strip()
    
    match_stats['date'] = match_stats['date_location'].split(',')[-2]
    match_stats['time'] = match_stats['date_location'].split('-')[-1]
    return(match_stats)

# %%
stats_test = match_stats(links[1])

# %%
stats_test
# Out:
# {'away_attck_pass': 86,
#  'away_crnr': 4,
#  'away_fouls': 6,
#  'away_pass_cmplt': 334,
#  'away_possession': 40.4,
#  'away_shots': 5,
#  'date': u' May 15',
#  'date_location': u'Emirates Stadium London, Sunday, May 15, 2016 - 15:00',
#  'home_attck_pass': 283,
#  'home_crnr': 5,
#  'home_fouls': 12,
#  'home_pass_cmplt': 537,
#  'home_possession': 59.6,
#  'home_shots': 16,
#  'time': u' 15:00'}

# %%
posession

# %%
#this is updated to output home and away team dictionaries
#[ToDo] copy over to the updated class

def player_links(game_link):
    url = game_link + '/player-stats#tabs-wrapper-anchor'

    
    session = dryscrape.Session()
    session.visit(url)
    formatted_result = session.body()
    

    soup = BeautifulSoup(formatted_result, 'html5')
    home_players = soup.findAll('div', {'class': 'lineup home'})
    away_players = soup.findAll('div', {'class': 'lineup away'})


    home_player_urls = ['http://www.fourfourtwo.com' + player.findAll('a')[0]['href'] 
       for player in home_players]
    home_player_names = [player.findAll('a')[0].contents
       for player in home_players]

    away_player_urls = ['http://www.fourfourtwo.com' + player.findAll('a')[0]['href'] 
       for player in away_players]
    away_player_names = [player.findAll('a')[0].contents
       for player in away_players]

    home_players = {}
    for i in range(len(home_player_names)):
        home_players[home_player_names[i][0]] = {"link":home_player_urls[i] }

    away_players = {}
    for i in range(len(away_player_names)):
        away_players[away_player_names[i][0]] = {"link":away_player_urls[i] }
    
    return(home_players, away_players)

# %%
home, away = player_links('http://www.fourfourtwo.com/statszone/8-2015/matches/803532')

# %%
away
# Out:
# {u'Ayew': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/80146/OVERALL_02#tabs-wrapper-anchor'},
#  u'Bacuna': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/74297/OVERALL_02#tabs-wrapper-anchor'},
#  u'Bunn': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/10954/OVERALL_02#tabs-wrapper-anchor'},
#  u'Cissokho': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/44354/OVERALL_02#tabs-wrapper-anchor'},
#  u'Gueye': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/80801/OVERALL_02#tabs-wrapper-anchor'},
#  u'Lescott': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/7551/OVERALL_02#tabs-wrapper-anchor'},
#  u'Lyden': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/160220/OVERALL_02#tabs-wrapper-anchor'},
#  u'Sinclair': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/19688/OVERALL_02#tabs-wrapper-anchor'},
#  u'S\xe1nchez': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/42824/OVERALL_02#tabs-wrapper-anchor'},
#  u'Toner': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/171213/OVERALL_02#tabs-wrapper-anchor'},
#  u'Westwood': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/60551/OVERALL_02#tabs-wrapper-anchor'}}

# %%
game_link = 'http://www.fourfourtwo.com/statszone/8-2015/matches/803532'
url = game_link + '/player-stats#tabs-wrapper-anchor'


session = dryscrape.Session()
session.visit(url)
formatted_result = session.body()

soup = BeautifulSoup(formatted_result, 'html5')
home_players = soup.findAll('div', {'class': 'lineup home'})
away_players = soup.findAll('div', {'class': 'lineup away'})


home_player_urls = ['http://www.fourfourtwo.com' + player.findAll('a')[0]['href'] 
   for player in home_players]
home_player_names = [player.findAll('a')[0].contents
   for player in home_players]

away_player_urls = ['http://www.fourfourtwo.com' + player.findAll('a')[0]['href'] 
   for player in away_players]
away_player_names = [player.findAll('a')[0].contents
   for player in away_players]
    
home_players = {}
for i in range(len(home_player_names)):
    home_players[home_player_names[i][0]] = {"link":home_player_urls[i] }
        
away_players = {}
for i in range(len(away_player_names)):
    away_players[away_player_names[i][0]] = {"link":away_player_urls[i] }

# %%
away_players
# Out:
# {u'Ayew': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/80146/OVERALL_02#tabs-wrapper-anchor'},
#  u'Bacuna': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/74297/OVERALL_02#tabs-wrapper-anchor'},
#  u'Bunn': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/10954/OVERALL_02#tabs-wrapper-anchor'},
#  u'Cissokho': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/44354/OVERALL_02#tabs-wrapper-anchor'},
#  u'Gueye': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/80801/OVERALL_02#tabs-wrapper-anchor'},
#  u'Lescott': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/7551/OVERALL_02#tabs-wrapper-anchor'},
#  u'Lyden': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/160220/OVERALL_02#tabs-wrapper-anchor'},
#  u'Sinclair': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/19688/OVERALL_02#tabs-wrapper-anchor'},
#  u'S\xe1nchez': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/42824/OVERALL_02#tabs-wrapper-anchor'},
#  u'Toner': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/171213/OVERALL_02#tabs-wrapper-anchor'},
#  u'Westwood': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/60551/OVERALL_02#tabs-wrapper-anchor'}}

# %%
away_player_names[0][0]
# Out:
# u'Bunn'

# %%
# Out:
# u'/statszone/8-2015/matches/803532/player-stats/11334/OVERALL_02#tabs-wrapper-anchor'

# %%
players = [for a in home_players]
# Out:
# 11

# %%
players = player_links('http://www.fourfourtwo.com/statszone/8-2015/matches/803532')
# Out:
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/lucas/anaconda2/envs/football/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))

# %%
players
# Out:
# {u'Ayew': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/80146/OVERALL_02#tabs-wrapper-anchor'},
#  u'Bacuna': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/74297/OVERALL_02#tabs-wrapper-anchor'},
#  u'Beller\xedn': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/98745/OVERALL_02#tabs-wrapper-anchor'},
#  u'Bunn': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/10954/OVERALL_02#tabs-wrapper-anchor'},
#  u'Cazorla': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/19524/OVERALL_02#tabs-wrapper-anchor'},
#  u'Cech': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/11334/OVERALL_02#tabs-wrapper-anchor'},
#  u'Cissokho': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/44354/OVERALL_02#tabs-wrapper-anchor'},
#  u'Coquelin': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/56864/OVERALL_02#tabs-wrapper-anchor'},
#  u'Giroud': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/44346/OVERALL_02#tabs-wrapper-anchor'},
#  u'Gueye': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/80801/OVERALL_02#tabs-wrapper-anchor'},
#  u'Koscielny': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/51507/OVERALL_02#tabs-wrapper-anchor'},
#  u'Lescott': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/7551/OVERALL_02#tabs-wrapper-anchor'},
#  u'Lyden': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/160220/OVERALL_02#tabs-wrapper-anchor'},
#  u'Monreal': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/38411/OVERALL_02#tabs-wrapper-anchor'},
#  u'Sinclair': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/19688/OVERALL_02#tabs-wrapper-anchor'},
#  u'S\xe1nchez': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/37265/OVERALL_02#tabs-wrapper-anchor'},
#  u'Toner': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/171213/OVERALL_02#tabs-wrapper-anchor'},
#  u'Westwood': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/60551/OVERALL_02#tabs-wrapper-anchor'},
#  u'Wilshere': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/54102/OVERALL_02#tabs-wrapper-anchor'},
#  u'de Abreu': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/158074/OVERALL_02#tabs-wrapper-anchor'},
#  u'\xd6zil': {'link': u'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/37605/OVERALL_02#tabs-wrapper-anchor'}}

# %%
def player_stats(url):
    #
    playerPage = Render(url)
    playerPageRendered = playerPage.frame.toHtml()
    playerPageFormatted = str(playerPageRendered.toAscii())
    playerSoup = BeautifulSoup(playerPageFormatted, 'html5')
    
    match_stats = {}
    #passes
    match_stats['pass_success'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallblue)'}))
    match_stats['pass_fail'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallred)'}))
    match_stats['chances'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smalldeepskyblue)'}))
    match_stats['assists'] = len(playerSoup.findAll('line', {'marker-end': 'url(#smallyellow)'}))

    #shots
    match_stats['on_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'}))
    match_stats['off_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigredend)'}))
    match_stats['on_target'] = len(playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'}))
    match_stats['goals'] = len(playerSoup.findAll('line', {'marker-start': 'url(#bigyellowend)'}))

    #takeons
    match_stats['takeon_success'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/success.png'}))
    match_stats['takeon_fail'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/fail.png'}))

    #defensive
    match_stats['fail_tkl'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png'}))
    match_stats['success_tkl'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png'}))
    match_stats['success_clearence'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearence.png'}))
    match_stats['failed_clearence'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearence.png'}))
    match_stats['interception'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png'}))
    match_stats['ball_recovery'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/defensive-ball-clearence.png'}))
    match_stats['blocks'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png'}))
    match_stats['blocks_cross'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks-cross.png'}))

    #aerial
    match_stats['aerial_won'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/won.png'}))
    match_stats['aerial_lost'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/lost.png'}))

    #fouls
    match_stats['foul_cmt'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png'}))
    match_stats['foul_sfr'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/suffered.png'}))

    #errors
    match_stats['error_goal'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-goal.png'}))
    match_stats['error_shot'] = len(playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-shot.png'}))
    
    return(match_stats)

# %%
url = players['Gueye']['link']

# %%
stats = player_stats('http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/80801/OVERALL_02#tabs-wrapper-anchor')
# Out:
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/lucas/anaconda2/envs/football/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))

# %%
stats
# Out:
# {'aerial_lost': 0,
#  'aerial_won': 0,
#  'assists': 0,
#  'ball_recovery': 0,
#  'blocks': 0,
#  'blocks_cross': 0,
#  'chances': 1,
#  'error_goal': 0,
#  'error_shot': 0,
#  'fail_tkl': 0,
#  'failed_clearence': 0,
#  'foul_cmt': 2,
#  'foul_sfr': 1,
#  'goals': 0,
#  'interception': 1,
#  'off_target': 0,
#  'on_target': 0,
#  'pass_fail': 7,
#  'pass_success': 53,
#  'success_clearence': 0,
#  'success_tkl': 2,
#  'takeon_fail': 2,
#  'takeon_success': 2}

# %%
len(stats['aerial_lost'])
# Out:
# 0

# %%
playerPage = Render('http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/80801/OVERALL_02#tabs-wrapper-anchor')
playerPageRendered = playerPage.frame.toHtml()
playerPageFormatted = str(playerPageRendered.toAscii())
playerSoup = BeautifulSoup(playerPageFormatted, 'html5')
# Out:
# /home/lucas/anaconda2/envs/football/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/lucas/anaconda2/envs/football/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))

# %%
#
playerPage = Render(url)
playerPageRendered = playerPage.frame.toHtml()
playerPageFormatted = str(playerPageRendered.toAscii())
playerSoup = BeautifulSoup(playerPageFormatted, 'html5')

match_stats = {}
#passes
match_stats['pass_success'] = playerSoup.findAll('line', {'marker-end': 'url(#smallblue)'})
match_stats['pass_fail'] = playerSoup.findAll('line', {'marker-end': 'url(#smallred)'})
match_stats['chances'] = playerSoup.findAll('line', {'marker-end': 'url(#smalldeepskyblue)'})
match_stats['assists'] = playerSoup.findAll('line', {'marker-end': 'url(#smallyellow)'})

#shots
match_stats['on_target'] = playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'})
match_stats['off_target'] = playerSoup.findAll('line', {'marker-end': 'url(#bigredend)'})
match_stats['on_target'] = playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'})
match_stats['goals'] = playerSoup.findAll('line', {'marker-start': 'url(#bigyellowend)'})

#takeons
match_stats['takeon_success'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/success.png'})
match_stats['takeon_fail'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/fail.png'})

#defensive
match_stats['fail_tkl'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png'})
match_stats['success_tkl'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png'})
match_stats['success_clearence'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearence.png'})
match_stats['failed_clearence'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearence.png'})
match_stats['interception'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png'})
match_stats['ball_recovery'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/defensive-ball-clearence.png'})
match_stats['blocks'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png'})
match_stats['blocks_cross'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks-cross.png'})

#aerial
match_stats['aerial_won'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/won.png'})
match_stats['aerial_lost'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/lost.png'})

#fouls
match_stats['foul_cmt'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png'})
match_stats['foul_sfr'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/suffered.png'})

#errors
match_stats['error_goal'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-goal.png'})
match_stats['error_shot'] = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-shot.png'})

# %%
players.keys()[1]
# Out:
# u'Gueye'

# %%
stats = player_stats(players['Gueye']['link'])

# %%
url = 'http://www.fourfourtwo.com/statszone/8-2015/matches/803532/player-stats/37265/OVERALL_02#tabs-wrapper-anchor'
playerPage = Render(url)
playerPageRendered = playerPage.frame.toHtml()
playerPageFormatted = str(playerPageRendered.toAscii())
playerSoup = BeautifulSoup(playerPageFormatted, 'html5')
# Out:
# /Users/lucaslafone/anaconda/envs/MLlib/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))

# %%
soup.findAll('line', {'marker-start': 'url(#bigyellowend)'})
# Out:
# [<line class="pitch-object timer-1-4" marker-end="url(#bigyellow)" marker-start="url(#bigyellowend)" style="stroke:yellow;stroke-width:3" x1="621.16" x2="692" y1="258.095" y2="246.139"></line>,
#  <line class="pitch-object timer-2-77" marker-end="url(#bigyellow)" marker-start="url(#bigyellowend)" style="stroke:yellow;stroke-width:3" x1="658.512" x2="692" y1="230.34" y2="264.073"></line>,
#  <line class="pitch-object timer-2-79" marker-end="url(#bigyellow)" marker-start="url(#bigyellowend)" style="stroke:yellow;stroke-width:3" x1="643.7" x2="692" y1="234.183" y2="255.96"></line>]

# %%
soup.findAll('image', {'xlink:href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/success.png'})
# Out:
# []

# %%
len(chances)
# Out:
# 4

# %%
#passes
pass_success = playerSoup.findAll('line', {'marker-end': 'url(#smallblue)'})
pass_fail = playerSoup.findAll('line', {'marker-end': 'url(#smallred)'})
chances = playerSoup.findAll('line', {'marker-end': 'url(#smalldeepskyblue)'})
assists = playerSoup.findAll('line', {'marker-end': 'url(#smallyellow)'})

#shots
on_target = playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'})
off_target = playerSoup.findAll('line', {'marker-end': 'url(#bigredend)'})
on_target = playerSoup.findAll('line', {'marker-end': 'url(#bigblueend)'})
goals = playerSoup.findAll('line', {'marker-start': 'url(#bigyellowend)'})

#takeons
takeon_success = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/success.png'})
takeon_fail = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/fail.png'})

#defensive
fail_tkl = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png'})
success_tkl = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png'})
success_clearence = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearence.png'})
failed_clearence = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearence.png'})
interception = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png'})
ball_recovery = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/defensive-ball-clearence.png'})
blocks = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png'})
blocks_cross = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks-cross.png'})

#aerial
aerial_won = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/won.png'})
aerial_lost = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/lost.png'})

#fouls
foul_cmt = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png'})
foul_sfr = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/suffered.png'})

#errors
error_goal = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-goal.png'})
error_shot = playerSoup.findAll('image', {'href': '/sites/fourfourtwo.com/modules/custom/statzone/files/icons/error-leading-shot.png'})

# %%
len(goals)
len(pass_success)
# Out:
# 42

# %%
# Out:
# [<image height="529" width="740" x="0" xlink:href="/sites/fourfourtwo.com/modules/custom/statzone/files/statszone_football_pitch.png" y="0">]
